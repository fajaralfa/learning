# %%
import os
os.environ["USE_NNPACK"] = "0"

import torch
if hasattr(torch.backends, 'nnpack'):
    torch.backends.nnpack.enabled = False
from torchvision.models import resnet18, ResNet18_Weights
model = resnet18(weights=ResNet18_Weights.DEFAULT)
data = torch.rand(1, 3, 64, 64)
labels = torch.rand(1, 1000)

# %%
prediction = model(data)
loss = (prediction - labels).sum()
loss.backward()
# Out:
# [W706 22:57:10.136878752 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.141205584 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.141821890 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.153248187 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.162228565 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.162716061 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.163238933 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.163539821 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.164058206 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.164616385 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.165062758 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.165912788 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.166224672 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.172610367 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.173621546 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.174905448 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.177333705 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.177940414 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.185110797 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.196605274 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.205318520 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.214639167 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.215230963 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.224469106 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.228507743 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.230351488 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.231873187 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.232234905 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.233800761 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.234838984 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.236385088 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.237382429 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.237629761 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.238542023 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.239304803 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.240377601 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.241240868 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W706 22:57:10.242169580 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
optim.step()

# %%
import torch

a = torch.tensor([2., 3.], requires_grad=True)
b = torch.tensor([6., 4.], requires_grad=True)

# %%
Q = 3*a**3 - b**2

# %%
external_grad = torch.tensor([1., 1.])
Q.backward(gradient=external_grad)

# %%
# check if collected gradients are correct
print(9*a**2 == a.grad)
print(-2*b == b.grad)
# Out:
# tensor([True, True])
# tensor([True, True])

# %%
# DAG Exclusion

x = torch.rand(5, 5)
y = torch.rand(5, 5)
z = torch.rand((5, 5), requires_grad=True)

a = x + y
print(f"Does `a` require gradients?: {a.requires_grad}")
b = x + z
print(f"Does `b` require gradients?: {b.requires_grad}")
# Out:
# Does `a` require gradients?: False
# Does `b` require gradients?: True

# %%
from torch import nn, optim

model = resnet18(weights=ResNet18_Weights.DEFAULT)

# Freeze all the parameters in the network
for param in model.parameters():
    param.requires_grad = False

# %%
model.fc = nn.Linear(512, 10)

# %%
optimizer = optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
optimizer.step()
