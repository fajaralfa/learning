# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('./data_jobs/')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Indonesia']).any()
# Out:
# np.True_

# %%
id_jobs = df[df['job_country'] == 'Indonesia']

# %%
id_jobs = id_jobs[id_jobs['salary_year_avg'].notna()]
id_jobs
# Out:
#                   job_title_short  \
# 132684             Data Scientist
# 147015           Business Analyst
# 229531               Data Analyst
# 239163               Data Analyst
# 294963  Machine Learning Engineer
# 303696               Data Analyst
# 305268              Data Engineer
# 335117      Senior Data Scientist
# 341109             Data Scientist
# 343560               Data Analyst
# 355207           Business Analyst
# 377901       Senior Data Engineer
# 404125               Data Analyst
# 404496        Senior Data Analyst
# 426363              Data Engineer
# 434286              Data Engineer
# 471660               Data Analyst
# 514316               Data Analyst
# 520816             Data Scientist
# 527097          Software Engineer
# 530811              Data Engineer
# 542880        Senior Data Analyst
# 554451        Senior Data Analyst
# 574971             Data Scientist
# 586699              Data Engineer
# 586753               Data Analyst
# ...

# %%
id_jobs.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                             37        37.000000              0.0
# mean   2023-07-01 11:12:42.135135232     99529.945946              NaN
# min              2023-01-05 23:40:13     50400.000000              NaN
# 25%              2023-05-02 08:19:40     64800.000000              NaN
# 50%              2023-07-05 19:19:23    100500.000000              NaN
# 75%              2023-08-29 19:37:44    131580.000000              NaN
# max              2023-12-22 21:17:32    166000.000000              NaN
# std                              NaN     35543.161352              NaN

# %%
id_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'max']).sort_values(by='median')
# Out:
#                              median       max
# job_title_short
# Business Analyst            64800.0   64800.0
# Data Analyst                77017.5  132500.0
# Data Scientist              90000.5  157500.0
# Senior Data Analyst        111175.0  111175.0
# Machine Learning Engineer  115400.0  166000.0
# Senior Data Scientist      118350.0  157500.0
# Software Engineer          123000.0  123000.0
# Data Engineer              132910.5  147500.0
# Senior Data Engineer       147500.0  147500.0
